# %% [markdown]
# <a href="https://colab.research.google.com/github/matahj/accidentesTransitoCDMX/blob/main/notebooks/accidentesEDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Análisis exploratorio de datos
#
# ---
#
# Se analizan datos sobre accidentes de tránsito obtenidos de fuentes abiertas, limpiados previamente.
#
# ---

# %%
import pandas as pd

# %%
# Se descarga, de github, la hoja de cálculo con los datos.

# !wget https://github.com/matahj/accidentesTransitoCDMX/raw/refs/heads/main/datos/base_2024.xlsx

# %%
# Se cargan los datos en un data frame.

df = pd.read_excel('base_2024.xlsx')
df.head()
# Out:
#   fecha_evento hora_evento  tipo_evento fecha_captura              folio  \
# 0   01/01/2024       08:03  ATROPELLADO    12/02/2024  C5/20240101/02177
# 1   01/01/2024       14:56  ATROPELLADO    12/02/2024  C5/20240101/03566
# 2   01/01/2024       21:11  ATROPELLADO    12/02/2024  C5/20240101/05341
# 3   01/01/2024       22:38  ATROPELLADO    12/02/2024  C5/20240101/05779
# 4   01/01/2024       00:34       CHOQUE    12/02/2024  C5/20240101/00182
#
#      latitud   longitud                 punto_1             punto_2  \
# 0  19.235238 -99.124109  LIC MARTINEZ DE CASTRO     PINA Y PALACIOS
# 1  19.413139 -99.141246           SIMON BOLIVAR    FERNANDO RAMIREZ
# 2  19.325140 -99.158258              AV AZTECAS  REYNA IXTLIXOCHITL
# 3  19.488136 -99.126116               EJE 5 NTE                CALI
# 4  19.271021 -99.000268         20 DE NOVIEMBRE         JAVIER MINA
#
#            colonia  ... clasificacion_de_la_vialidad  sentido_de_circulacion  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30652 entries, 0 to 30651
# Data columns (total 26 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   fecha_evento                  30652 non-null  object
#  1   hora_evento                   30652 non-null  object
#  2   tipo_evento                   30652 non-null  object
#  3   fecha_captura                 30652 non-null  object
#  4   folio                         30652 non-null  object
#  5   latitud                       30652 non-null  float64
#  6   longitud                      30652 non-null  float64
#  7   punto_1                       30652 non-null  object
#  8   punto_2                       30651 non-null  object
#  9   colonia                       30652 non-null  object
#  10  alcaldia                      30652 non-null  object
#  11  zona_vial                     30652 non-null  int64
# ...
